# %% [markdown]
# # Getting started
#
# Once you've chosen your scenario, download the data from [the Iowa website](https://data.iowa.gov/Economy/Iowa-Liquor-Sales/m3tr-qhgy) in csv format. Start by loading the data with pandas. You may need to parse the date columns appropriately.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
# %matplotlib inline

# %%
# Named csv 'Iowa"
Iowa = pd.read_csv('/Users/macbook/GA-DSI/projects/projects-weekly/project-03/Iowa_Liquor_sales_sample_10pct.csv')

# %%
# Observe Data 
Iowa.head()
# Out:
#          Date  Store Number         City Zip Code  County Number      County  \
# 0  11/04/2015          3717       SUMNER    50674            9.0      Bremer
# 1  03/02/2016          2614    DAVENPORT    52807           82.0       Scott
# 2  02/11/2016          2106  CEDAR FALLS    50613            7.0  Black Hawk
# 3  02/03/2016          2501         AMES    50010           85.0       Story
# 4  08/18/2015          3654      BELMOND    50421           99.0      Wright
#
#     Category              Category Name  Vendor Number  Item Number  \
# 0  1051100.0           APRICOT BRANDIES             55        54436
# 1  1011100.0           BLENDED WHISKIES            395        27605
# 2  1011200.0  STRAIGHT BOURBON WHISKIES             65        19067
# 3  1071100.0         AMERICAN COCKTAILS            395        59154
# 4  1031080.0             VODKA 80 PROOF            297        35918
#
#             Item Description  Bottle Volume (ml) State Bottle Cost  \
# 0  Mr. Boston Apricot Brandy                 750             $4.50
# 1                    Tin Cup                 750            $13.75
# 2                   Jim Beam                1000            $12.59
# 3    1800 Ultimate Margarita                1750             $9.50
# 4         Five O'clock Vodka                1750             $7.20
#
#   State Bottle Retail  Bottles Sold Sale (Dollars)  Volume Sold (Liters)  \
# 0               $6.75            12         $81.00                   9.0
# 1              $20.63             2         $41.26                   1.5
# 2              $18.89            24        $453.36                  24.0
# 3              $14.25             6         $85.50                  10.5
# 4              $10.80            12        $129.60                  21.0
#
#    Volume Sold (Gallons)
# 0                   2.38
# 1                   0.40
# 2                   6.34
# 3                   2.77
# 4                   5.55

# %%
# Remove all NaN values

Iowa = Iowa.dropna()

# %%
Iowa.dtypes
# Out:
# Date                     datetime64[ns]
# Store Number                      int64
# City                             object
# Zip Code                          int64
# County Number                     int64
# County                           object
# Category                        float64
# Category Name                    object
# Vendor Number                     int64
# Item Number                       int64
# Item Description                 object
# Bottle Volume (ml)                int64
# State Bottle Cost                object
# State Bottle Retail              object
# Bottles Sold                      int64
# Sale (Dollars)                   object
# Volume Sold (Liters)            float64
# Volume Sold (Gallons)           float64
# dtype: object

# %%
# Change date to datetype
Iowa['Date'] = pd.to_datetime(Iowa['Date'], format="%m-%d-%y")

# %%
# Force zip codes to floats, change to ints
Iowa['Zip Code'] = pd.to_numeric(Iowa['Zip Code'], errors = 'coerce')
Iowa['Zip Code'] = Iowa.loc[:, ['Zip Code']].astype(int)

# %%
# Change County Number to int
Iowa['County Number'] = Iowa.loc[:, ['County Number']].astype(int)

# %%
Iowa.head()
# Out:
#         Date  Store Number         City  Zip Code  County Number      County  \
# 0 2015-11-04          3717       SUMNER     50674              9      Bremer
# 1 2016-03-02          2614    DAVENPORT     52807             82       Scott
# 2 2016-02-11          2106  CEDAR FALLS     50613              7  Black Hawk
# 3 2016-02-03          2501         AMES     50010             85       Story
# 4 2015-08-18          3654      BELMOND     50421             99      Wright
#
#     Category              Category Name  Vendor Number  Item Number  \
# 0  1051100.0           APRICOT BRANDIES             55        54436
# 1  1011100.0           BLENDED WHISKIES            395        27605
# 2  1011200.0  STRAIGHT BOURBON WHISKIES             65        19067
# 3  1071100.0         AMERICAN COCKTAILS            395        59154
# 4  1031080.0             VODKA 80 PROOF            297        35918
#
#             Item Description  Bottle Volume (ml) State Bottle Cost  \
# 0  Mr. Boston Apricot Brandy                 750             $4.50
# 1                    Tin Cup                 750            $13.75
# 2                   Jim Beam                1000            $12.59
# 3    1800 Ultimate Margarita                1750             $9.50
# 4         Five O'clock Vodka                1750             $7.20
#
#   State Bottle Retail  Bottles Sold Sale (Dollars)  Volume Sold (Liters)  \
# 0               $6.75            12         $81.00                   9.0
# 1              $20.63             2         $41.26                   1.5
# 2              $18.89            24        $453.36                  24.0
# 3              $14.25             6         $85.50                  10.5
# 4              $10.80            12        $129.60                  21.0
#
#    Volume Sold (Gallons)
# 0                   2.38
# 1                   0.40
# 2                   6.34
# 3                   2.77
# 4                   5.55

# %% [raw]
# # Double checking weird Date type. It is a subtype.
# Iowa['Date'].dt.month

# %%
# Checking for NaNs
Iowa.isnull().sum()
# Out:
# date                   0
# store_number           0
# city                   0
# zip_code               0
# county_number          0
# county                 0
# category               0
# category_name          0
# vendor_number          0
# item_number            0
# item_description       0
# bottle_volume          0
# state_bottle_cost      0
# state_bottle_retail    0
# bottles_sold           0
# sales                  0
# volume_sold            0
# volume_sold_gallons    0
# dtype: int64

# %%
# Clean up column names 1: remove units of measurement
Iowa.rename(columns = {'Bottle Volume (ml)': 'Bottle Volume', 'Sale (Dollars)': 'Sales', \
                      'Volume Sold (Liters)': 'Volume Sold', \
                       'Volume Sold (Gallons)': 'Volume Sold Gallons'}, inplace=True)

# Clean up column names 2: convert all to lowercase letters
import string 
lower = string.ascii_lowercase
Iowa.rename(columns = lambda x: x.lower(), inplace=True)

# Clean up column names 3: replace '', '(' and ')'
Iowa.rename(columns = lambda x: x.replace(' ', '_'), inplace=True)
Iowa.rename(columns = lambda x: x.replace('(', ''), inplace=True)
Iowa.rename(columns = lambda x: x.replace(')', ''), inplace=True)

# %%
Iowa.head()
# Out:
#         date  store_number         city  zip_code  county_number      county  \
# 0 2015-11-04          3717       SUMNER     50674              9      Bremer
# 1 2016-03-02          2614    DAVENPORT     52807             82       Scott
# 2 2016-02-11          2106  CEDAR FALLS     50613              7  Black Hawk
# 3 2016-02-03          2501         AMES     50010             85       Story
# 4 2015-08-18          3654      BELMOND     50421             99      Wright
#
#     category              category_name  vendor_number  item_number  \
# 0  1051100.0           APRICOT BRANDIES             55        54436
# 1  1011100.0           BLENDED WHISKIES            395        27605
# 2  1011200.0  STRAIGHT BOURBON WHISKIES             65        19067
# 3  1071100.0         AMERICAN COCKTAILS            395        59154
# 4  1031080.0             VODKA 80 PROOF            297        35918
#
#             item_description  bottle_volume state_bottle_cost  \
# 0  Mr. Boston Apricot Brandy            750              4.50
# 1                    Tin Cup            750             13.75
# 2                   Jim Beam           1000             12.59
# 3    1800 Ultimate Margarita           1750              9.50
# 4         Five O'clock Vodka           1750              7.20
#
#   state_bottle_retail  bottles_sold   sales  volume_sold  volume_sold_gallons
# 0                6.75            12   81.00          9.0                 2.38
# 1               20.63             2   41.26          1.5                 0.40
# 2               18.89            24  453.36         24.0                 6.34
# 3               14.25             6   85.50         10.5                 2.77
# 4               10.80            12  129.60         21.0                 5.55

# %%
# Changing types of all dollar columns

Iowa['state_bottle_retail'] = Iowa['state_bottle_retail'].str.replace('$', '')
Iowa['state_bottle_cost'] = Iowa['state_bottle_cost'].str.replace('$', '')
Iowa['sales'] = Iowa['sales'].str.replace('$', '')

Iowa['state_bottle_retail'] = Iowa.loc[:, ['state_bottle_retail']].astype(float)
Iowa['state_bottle_cost'] = Iowa.loc[:, ['state_bottle_cost']].astype(float)
Iowa['sales'] = Iowa.loc[:, ['sales']].astype(float)

# %%
category_df = Iowa.groupby('category')[['category', 'category_name']]
desc_df = Iowa.groupby('item_number')[['item_number', 'item_description']]
county_df = Iowa.groupby('county_number')[['county_number', 'county']]

# %%
category_df.head(3)
# Out:
#          category                       category_name
# 0       1051100.0                    APRICOT BRANDIES
# 1       1011100.0                    BLENDED WHISKIES
# 2       1011200.0           STRAIGHT BOURBON WHISKIES
# 3       1071100.0                  AMERICAN COCKTAILS
# 4       1031080.0                      VODKA 80 PROOF
# 5       1041100.0                   AMERICAN DRY GINS
# 6       1051010.0             AMERICAN GRAPE BRANDIES
# 7       1012100.0                   CANADIAN WHISKIES
# 8       1032080.0                      IMPORTED VODKA
# 9       1081315.0                   CINNAMON SCHNAPPS
# 10      1011250.0      SINGLE BARREL BOURBON WHISKIES
# 11      1071100.0                  AMERICAN COCKTAILS
# 12      1012100.0                   CANADIAN WHISKIES
# 13      1081300.0                 PEPPERMINT SCHNAPPS
# 14      1031200.0                      VODKA FLAVORED
# 15      1051100.0                    APRICOT BRANDIES
# 16      1031100.0                     100 PROOF VODKA
# 17      1031200.0                      VODKA FLAVORED
# 18      1081700.0         DISTILLED SPIRITS SPECIALTY
# 19      1012100.0                   CANADIAN WHISKIES
# 20      1031200.0                      VODKA FLAVORED
# 22      1011100.0                    BLENDED WHISKIES
# 23      1022100.0                             TEQUILA
# 24      1031080.0                      VODKA 80 PROOF
# 25      1011300.0                  TENNESSEE WHISKIES
# 27      1011100.0                    BLENDED WHISKIES
# 28      1031080.0                      VODKA 80 PROOF
# 29      1081600.0                     WHISKEY LIQUEUR
# 30      1041100.0                   AMERICAN DRY GINS
# 31      1081900.0  MISC. AMERICAN CORDIALS & LIQUEURS
# ...           ...                                 ...
# 4013    1081220.0                 DARK CREME DE CACAO
# 4260    1081500.0                          ROCK & RYE
# 4263    1081015.0                   IMPORTED AMARETTO
# 4600    1081015.0                   IMPORTED AMARETTO
# 5230    1081240.0               GREEN CREME DE MENTHE
# 5347    1081230.0                WHITE CREME DE CACAO
# 5734    1081250.0               WHITE CREME DE MENTHE
# 5742    1031090.0                   OTHER PROOF VODKA
# 5906    1081500.0                          ROCK & RYE
# 6276    1081210.0                     CREME DE ALMOND
# 7538    1012400.0                     JAPANESE WHISKY
# 8585    1011400.0             BOTTLED IN BOND BOURBON
# 8734    1081250.0               WHITE CREME DE MENTHE
# 9349    1011400.0             BOTTLED IN BOND BOURBON
# 10435   1081210.0                     CREME DE ALMOND
# 13204   1011600.0                       CORN WHISKIES
# 16233   1011600.0                       CORN WHISKIES
# 19878   1081020.0                            ANISETTE
# 23586   1501100.0          HIGH PROOF BEER - AMERICAN
# 30554   1081020.0                            ANISETTE
# 35088   1012400.0                     JAPANESE WHISKY
# 38154   1031110.0                     LOW PROOF VODKA
# 42952   1031110.0                     LOW PROOF VODKA
# 46247   1011600.0                       CORN WHISKIES
# 116314  1082010.0                 AMARETTO - IMPORTED
# 131594  1501100.0          HIGH PROOF BEER - AMERICAN
# 132143  1082010.0                 AMARETTO - IMPORTED
# 137635  1082015.0                   IMPORTED AMARETTO
# 225665  1082010.0                 AMARETTO - IMPORTED
# 265155  1082015.0                   IMPORTED AMARETTO
#
# [214 rows x 2 columns]

# %%
# Generalize categories

#vodka
#schnapps
#whiskey
#rum
#scotch
#gin
#liqueurs
#brandies
#tequila
#beer
#other

# %%
# Create a Year column.

Iowa['year'] = Iowa['date'].map(lambda x: x.year)

# %%
#Create profit per bottle and total profit per category
Iowa["profit_per_bottle"] = (Iowa["state_bottle_retail"] - Iowa["state_bottle_cost"]) * Iowa["bottles_sold"]
Iowa['total_profit'] = (Iowa['profit_per_bottle']  * Iowa['bottles_sold'])
Iowa.head()
# Out:
#         date  store_number         city  zip_code  county_number      county  \
# 0 2015-11-04          3717       SUMNER     50674              9      Bremer
# 1 2016-03-02          2614    DAVENPORT     52807             82       Scott
# 2 2016-02-11          2106  CEDAR FALLS     50613              7  Black Hawk
# 3 2016-02-03          2501         AMES     50010             85       Story
# 4 2015-08-18          3654      BELMOND     50421             99      Wright
#
#     category              category_name  vendor_number  item_number  \
# 0  1051100.0           APRICOT BRANDIES             55        54436
# 1  1011100.0           BLENDED WHISKIES            395        27605
# 2  1011200.0  STRAIGHT BOURBON WHISKIES             65        19067
# 3  1071100.0         AMERICAN COCKTAILS            395        59154
# 4  1031080.0             VODKA 80 PROOF            297        35918
#
#        ...      state_bottle_retail  bottles_sold   sales  volume_sold  \
# 0      ...                     6.75            12   81.00          9.0
# 1      ...                    20.63             2   41.26          1.5
# 2      ...                    18.89            24  453.36         24.0
# 3      ...                    14.25             6   85.50         10.5
# 4      ...                    10.80            12  129.60         21.0
#
#    volume_sold_gallons  Year  year  profit  profit_per_bottle  total_profit
# 0                 2.38  2015  2015   27.00              27.00        324.00
# 1                 0.40  2016  2016   13.76              13.76         27.52
# 2                 6.34  2016  2016  151.20             151.20       3628.80
# 3                 2.77  2016  2016   28.50              28.50        171.00
# 4                 5.55  2015  2015   43.20              43.20        518.40
#
# [5 rows x 23 columns]

# %%
# Chart profit per county per type
profit_county_per_type = Iowa.groupby('county')[('county', 'category_name', 'total_profit')]
profit_county_per_type.head(5)
# Out:
#               county                       category_name  total_profit
# 0             Bremer                    APRICOT BRANDIES        324.00
# 1              Scott                    BLENDED WHISKIES         27.52
# 2         Black Hawk           STRAIGHT BOURBON WHISKIES       3628.80
# 3              Story                  AMERICAN COCKTAILS        171.00
# 4             Wright                      VODKA 80 PROOF        518.40
# 5               Linn                   AMERICAN DRY GINS        239.76
# 6            Wapello             AMERICAN GRAPE BRANDIES         29.97
# 7        Cerro Gordo                   CANADIAN WHISKIES         31.52
# 8               Polk                      IMPORTED VODKA         92.00
# 9             Benton                   CINNAMON SCHNAPPS         15.24
# 10              Polk      SINGLE BARREL BOURBON WHISKIES        472.32
# 11           Mahaska                  AMERICAN COCKTAILS        117.00
# 12             Scott                   CANADIAN WHISKIES          4.46
# 13               Lee                 PEPPERMINT SCHNAPPS        720.00
# 14           Johnson                      VODKA FLAVORED        540.00
# 15            Bremer                    APRICOT BRANDIES         36.00
# 16        Black Hawk                     100 PROOF VODKA       1313.28
# 17           Mahaska                      VODKA FLAVORED        468.00
# 18            Jasper         DISTILLED SPIRITS SPECIALTY       1416.96
# 19             Scott                   CANADIAN WHISKIES        179.64
# 20              Linn                      VODKA FLAVORED         28.52
# 21              Tama                   CANADIAN WHISKIES        377.28
# 22             Sioux                    BLENDED WHISKIES        504.00
# 23       Cerro Gordo                             TEQUILA        756.00
# 24              Linn                      VODKA 80 PROOF        243.36
# 25         Dickinson                  TENNESSEE WHISKIES       5155.20
# 26           Johnson                   CANADIAN WHISKIES          3.68
# 27     Pottawattamie                    BLENDED WHISKIES         15.75
# 28              Polk                      VODKA 80 PROOF        198.00
# 29           Johnson                     WHISKEY LIQUEUR          2.45
# ...              ...                                 ...           ...
# 4479           Wayne                      IMPORTED VODKA       1332.00
# 4482       Van Buren                     WHISKEY LIQUEUR         91.17
# 4510         Guthrie                      VODKA 80 PROOF        128.16
# 4704           Adams           STRAIGHT BOURBON WHISKIES          2.47
# 4819         Hancock                      IMPORTED VODKA         83.25
# 5103        Ringgold                  AMERICAN COCKTAILS         36.90
# 5128         Audubon                   CANADIAN WHISKIES        478.08
# 5228          Taylor                      VODKA 80 PROOF        518.40
# 5252          Monroe                      CREAM LIQUEURS        225.00
# 5428          Taylor                      CREAM LIQUEURS         16.40
# 5574         Hancock                      VODKA 80 PROOF        292.32
# 5658           Adams                      VODKA FLAVORED         16.52
# 6115          Monroe                      VODKA FLAVORED         29.25
# 6403         Audubon                      VODKA 80 PROOF        128.16
# 6607          Monroe                   AMERICAN DRY GINS        189.00
# 6756         Audubon                  AMERICAN COCKTAILS        121.68
# 6807         Decatur    PUERTO RICO & VIRGIN ISLANDS RUM        141.12
# 6974           Wayne    PUERTO RICO & VIRGIN ISLANDS RUM        270.00
# 7245           Adams                   CINNAMON SCHNAPPS          7.92
# 7281         Fremont                    BLENDED WHISKIES        910.08
# 7364           Adams  MISC. AMERICAN CORDIALS & LIQUEURS         35.73
# 8004           Davis                      VODKA 80 PROOF        129.60
# 8122           Wayne  MISC. IMPORTED CORDIALS & LIQUEURS         54.27
# 9432        Ringgold           STRAIGHT BOURBON WHISKIES         24.84
# 11150        Audubon                    BLENDED WHISKIES        509.76
# 11229       Ringgold                      VODKA 80 PROOF        124.56
# 12114       Ringgold                      VODKA 80 PROOF        516.96
# 13592       Ringgold                   CANADIAN WHISKIES         31.50
# 24438        Fremont                          SPICED RUM        324.00
# 36010        Fremont                   CANADIAN WHISKIES        887.04
#
# [495 rows x 3 columns]

# %%
profit_store_per_type = Iowa.groupby('store_number')[('store_number', 'city', 'total_profit', 'year')]
profit_store_per_type.sort(['city', 'store_number', 'total_profit', 'year'], axis=1, 'True')
# Out:
#   File "<ipython-input-137-a3bdb008c7f7>", line 2
#     profit_store_per_type.sort(['city', 'store_number', 'total_profit', 'year'], axis=1, 'True')
# SyntaxError: non-keyword arg after keyword arg

# %%
store_profit = pd.pivot_table(Iowa, values=['city'], index=['store_number', 'total_profit', 'year'], aggfunc=np.sum)
store_profit.reset_index(inplace=True)
store_profit.drop('city', axis=1, inplace=True)
store_profit.head()
# Out:
#    store_number  total_profit  year
# 0          2106          1.65  2015
# 1          2106          1.87  2015
# 2          2106          2.35  2016
# 3          2106          2.40  2015
# 4          2106          2.45  2015

# %% [markdown]
# # Explore the data
#
# Perform some exploratory statistical analysis and make some plots, such as histograms of transaction totals, bottles sold, etc.

# %%
Iowa_cities = pd.pivot_table(Iowa, index=['city', 'year', 'store_number'], values=['total_profit'])

# %%
Iowa_cities

# %%
# Compute sales per county. Because I got confused.
county_year = Iowa.groupby(by=['county', 'year'], as_index=False)
# Compute sums, means
county_sales = county_year.agg({'sales': [np.sum, np.mean],                           
                           'volume_sold': [np.sum, np.mean],
                           'total_profit': [np.sum, np.mean]})

# %%
#Compute sales per store sum and mean
city_sales = Iowa.groupby(by=['store_number', 'city'], as_index=False)

store_sales = city_sales.agg({'sales':[np.sum, np.mean],
                             'volume_sold': [np.sum, np.mean],
                             'total_profit': [np.sum, np.mean]})
store_sales.head(3)
# Out:
#   store_number         city volume_sold            total_profit               \
#                                     sum       mean          sum         mean
# 0         2106  CEDAR FALLS    11836.10  18.153528   2389654.58  3665.114387
# 1         2113       GOWRIE      836.85   4.548098     31060.37   168.806359
# 2         2130     WATERLOO     8436.27  16.606831   2325516.39  4577.788169
#
#        sales
#          sum        mean
# 0  176517.45  270.732285
# 1   11376.12   61.826739
# 2  139440.02  274.488228

# %%
sns.pairplot(store_sales, kind="reg");

# %%
col_list = store_sales.columns

# %%
store_sales.loc[:, col_list].corr()
# Out:
#                   store_number volume_sold           total_profit            \
#                                        sum      mean          sum      mean
# store_number          1.000000   -0.376564  0.063240    -0.142464  0.117876
# volume_sold  sum     -0.376564    1.000000  0.318157     0.801099  0.176770
#              mean     0.063240    0.318157  1.000000     0.378496  0.866037
# total_profit sum     -0.142464    0.801099  0.378496     1.000000  0.313172
#              mean     0.117876    0.176770  0.866037     0.313172  1.000000
# sales        sum     -0.341854    0.992822  0.305013     0.804656  0.184558
#              mean     0.147089    0.213820  0.924602     0.275876  0.951448
#
#                       sales
#                         sum      mean
# store_number      -0.341854  0.147089
# volume_sold  sum   0.992822  0.213820
#              mean  0.305013  0.924602
# total_profit sum   0.804656  0.275876
#              mean  0.184558  0.951448
# sales        sum   1.000000  0.219980
#              mean  0.219980  1.000000

# %%
store_sales.columns
# Out:
# MultiIndex(levels=[[u'volume_sold', u'total_profit', u'sales', u'city', u'store_number'], [u'sum', u'mean', u'']],
#            labels=[[4, 3, 0, 0, 1, 1, 2, 2], [2, 2, 0, 1, 0, 1, 0, 1]])

# %%
store_sales['total_profit, sum'].plot(kind='bar', figsize=(16, 10), fontsize=14)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-156-1e2e3e71ba55> in <module>()
#       1
# ----> 2 store_sales['total_profit, sum'].plot(kind='bar', figsize=(16, 10), fontsize=14)
#
# /Users/macbook/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1993             return self._getitem_frame(key)
#    1994         elif is_mi_columns:
# -> 1995             return self._getitem_multilevel(key)
#    1996         else:
#    1997             return self._getitem_column(key)
#
# /Users/macbook/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_multilevel(self, key)
#    2037
#    2038     def _getitem_multilevel(self, key):
# -> 2039         loc = self.columns.get_loc(key)
#    2040         if isinstance(loc, (slice, Series, np.ndarray, Index)):
#    2041             new_columns = self.columns[loc]
#
# /Users/macbook/anaconda/lib/python2.7/site-packages/pandas/indexes/multi.pyc in get_loc(self, key, method)
#    1547
#    1548         if not isinstance(key, tuple):
# -> 1549             loc = self._get_level_indexer(key, level=0)
#    1550             return _maybe_to_slice(loc)
#    1551
#
# /Users/macbook/anaconda/lib/python2.7/site-packages/pandas/indexes/multi.pyc in _get_level_indexer(self, key, level, indexer)
#    1808         else:
#    1809
# -> 1810             loc = level_index.get_loc(key)
#    1811             if level > 0 or self.lexsort_depth == 0:
#    1812                 return np.array(labels == loc, dtype=bool)
#
# /Users/macbook/anaconda/lib/python2.7/site-packages/pandas/indexes/base.pyc in get_loc(self, key, method, tolerance)
#    1945                 return self._engine.get_loc(key)
#    1946             except KeyError:
# -> 1947                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    1948
#    1949         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4154)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4018)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12368)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12322)()
#
# KeyError: 'total_profit, sum'

# %% [markdown]
# ## Record your findings
#
# Be sure to write out anything observations from your exploratory analysis.

# %% [markdown]
# # Mine the data
# Now you are ready to compute the variables you will use for your regression from the data. For example, you may want to
# compute total sales per store from Jan to March of 2015, mean price per bottle, etc. Refer to the readme for more ideas appropriate to your scenario.
#
# Pandas is your friend for this task. Take a look at the operations [here](http://pandas.pydata.org/pandas-docs/stable/groupby.html) for ideas on how to make the best use of pandas and feel free to search for blog and Stack Overflow posts to help you group data by certain variables and compute sums, means, etc. You may find it useful to create a new data frame to house this summary data.

# %% [markdown]
# # Refine the data
# Look for any statistical relationships, correlations, or other relevant properties of the dataset.

# %% [markdown]
# # Build your models
#
# Using scikit-learn or statsmodels, build the necessary models for your scenario. Evaluate model fit.

# %%
from sklearn import linear_model

# %% [markdown]
# ## Plot your results
#
# Again make sure that you record any valuable information. For example, in the tax scenario, did you find the sales from the first three months of the year to be a good predictor of the total sales for the year? Plot the predictions versus the true values and discuss the successes and limitations of your models

# %% [markdown]
# # Present the Results
#
# Present your conclusions and results. If you have more than one interesting model feel free to include more than one along with a discussion. Use your work in this notebook to prepare your write-up.
