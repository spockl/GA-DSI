# %%
import pandas as pd
import numpy as np
bbdf = pd.read_csv('/Users/macbook/GA-DSI/projects/projects-weekly/project-02/billboard.csv', encoding='latin-1')
bbdf.head(5)

# Review of data
# Out:
#    year      artist.inverted                                  track  \
# 0  2000      Destiny's Child               Independent Women Part I
# 1  2000              Santana                           Maria, Maria
# 2  2000        Savage Garden                     I Knew I Loved You
# 3  2000              Madonna                                  Music
# 4  2000  Aguilera, Christina  Come On Over Baby (All I Want Is You)
#
#          time genre        date.entered         date.peaked  x1st.week  \
# 0  3,38,00 AM  Rock  September 23, 2000   November 18, 2000         78
# 1  4,18,00 AM  Rock   February 12, 2000       April 8, 2000         15
# 2  4,07,00 AM  Rock    October 23, 1999    January 29, 2000         71
# 3  3,45,00 AM  Rock     August 12, 2000  September 16, 2000         41
# 4  3,38,00 AM  Rock      August 5, 2000    October 14, 2000         57
#
#   x2nd.week x3rd.week    ...     x67th.week x68th.week x69th.week x70th.week  \
# ...

# %%
df["Date"] = pd.to_datetime(df["Date"], format="%m-%d-%y")

# %% [markdown]
# Question: Does chart level reached impact longevity on chart? In other words, if a song reaches the top 10, will it have more staying power or is it more likely to be a "one-hit wonder".

# %%
def replace_nulls(value):
    if value == '*':
        return np.nan
    else:
        return value

# %%
bbpro = bbdf.applymap(replace_nulls)

# %%
bbpro(10)
# Out:
#    year      artist.inverted                                  track  \
# 0  2000      Destiny's Child               Independent Women Part I
# 1  2000              Santana                           Maria, Maria
# 2  2000        Savage Garden                     I Knew I Loved You
# 3  2000              Madonna                                  Music
# 4  2000  Aguilera, Christina  Come On Over Baby (All I Want Is You)
# 5  2000                Janet                  Doesn't Really Matter
# 6  2000      Destiny's Child                            Say My Name
# 7  2000    Iglesias, Enrique                            Be With You
# 8  2000                Sisqo                             Incomplete
# 9  2000             Lonestar                                 Amazed
#
#          time        genre        date.entered         date.peaked  x1st.week  \
# 0  3,38,00 AM         Rock  September 23, 2000   November 18, 2000         78
# ...

# %%
# Check data types for columns
# Need to change data type for first week.
bbdf.dtypes.head(20)
# Out:
# year                int64
# artist.inverted    object
# track              object
# time               object
# genre              object
# date.entered       object
# date.peaked        object
# x1st.week           int64
# x2nd.week          object
# x3rd.week          object
# x4th.week          object
# x5th.week          object
# x6th.week          object
# x7th.week          object
# x8th.week          object
# x9th.week          object
# x10th.week         object
# x11th.week         object
# x12th.week         object
# x13th.week         object
# dtype: object

# %%
# Check data type for Time column.
# Need to format out of Unicode?
for i in bbdf['time']:
    print type(i)
# Out:
# <type 'unicode'>
# <type 'unicode'>
# <type 'unicode'>
# <type 'unicode'>
# <type 'unicode'>
# <type 'unicode'>
# <type 'unicode'>
# <type 'unicode'>
# <type 'unicode'>
# <type 'unicode'>
# <type 'unicode'>
# <type 'unicode'>
# <type 'unicode'>
# <type 'unicode'>
# <type 'unicode'>
# <type 'unicode'>
# <type 'unicode'>
# <type 'unicode'>
# <type 'unicode'>
# <type 'unicode'>
# <type 'unicode'>
# <type 'unicode'>
# <type 'unicode'>
# <type 'unicode'>
# <type 'unicode'>
# <type 'unicode'>
# <type 'unicode'>
# <type 'unicode'>
# <type 'unicode'>
# <type 'unicode'>
# <type 'unicode'>
# <type 'unicode'>
# <type 'unicode'>
# <type 'unicode'>
# <type 'unicode'>
# <type 'unicode'>
# <type 'unicode'>
# <type 'unicode'>
# <type 'unicode'>
# <type 'unicode'>
# <type 'unicode'>
# <type 'unicode'>
# <type 'unicode'>
# <type 'unicode'>
# <type 'unicode'>
# <type 'unicode'>
# <type 'unicode'>
# <type 'unicode'>
# <type 'unicode'>
# <type 'unicode'>
# <type 'unicode'>
# <type 'unicode'>
# ...

# %%
for x in bbdf['time']:
    x[0]
for x in ['length']:
    newX = x[0].replace("","")

# %%
print 'length'
# Out:
# length

# %%
['time_unicode = str(list[0][0])
date = datetime.datetime.strptime(date_unicode, '%Y-%m-%dT%H:%M:%S')
print date

# %%
new_time = []
for i in bbdf['time']:
    new_time.append((int(i[0]) * 60) + (int(i[2:])))

bbdf['time'] = new_time
bbdf.rename(columns={'time':'time_seconds'}, inplace=True)
print bbdf.head(3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-fc0ffdc93dd8> in <module>()
#       1 new_time = []
#       2 for i in bbdf['time']:
# ----> 3     new_time.append((int(i[0]) * 60) + (int(i[2:])))
#       4
#       5 bbdf['time'] = new_time
#
# ValueError: invalid literal for int() with base 10: '38,00 AM'

# %%
def get_sec(x):
    x_list = x.split(',')
    return int(x_list(0)) * 60 + int(x_list[1])

# %%
bbdf['track_length'] = bbdf['time'].map(get_sec).head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-34e9d85feb0a> in <module>()
# ----> 1 bbdf['track_length'] = bbdf['time'].map(get_sec).head()
#
# /Users/macbook/anaconda/lib/python2.7/site-packages/pandas/core/series.pyc in map(self, arg, na_action)
#    2102             new_values = algos.take_1d(arg._values, indexer)
#    2103         else:
# -> 2104             new_values = map_f(values, arg)
#    2105
#    2106         return self._constructor(new_values,
#
# pandas/src/inference.pyx in pandas.lib.map_infer (pandas/lib.c:62658)()
#
# <ipython-input-35-ded378d2ab9e> in get_sec(x)
#       1 def get_sec(x):
#       2     x_list = x.split(',')
# ----> 3     return int(x_list(0)) * 60 + int(x_list[1])
#
# TypeError: 'list' object is not callable

# %%
import time
time.strptime("30 Nov 00", "%d %b %y")   
time.struct_time(tm_year=2000, tm_mon=11, tm_mday=30, tm_hour=0, tm_min=0,
                 tm_sec=0, tm_wday=3, tm_yday=335, tm_isdst=-1)

# %%
bbdf(raw_input['time']).astype(int)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-56678ddeaa7f> in <module>()
# ----> 1 bbdf(raw_input['time']).astype(int)
#
# TypeError: 'instancemethod' object has no attribute '__getitem__'

# %%
new_time = []
for i in bbdf['time']:
    new_time.append((int(i[0]) * 60) + (int(i[2:])))

bbdf['time'] = new_time
bbdf.rename(columns={'time':'time_seconds'}, inplace=True)
print bbdf.head(3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-fc0ffdc93dd8> in <module>()
#       1 new_time = []
#       2 for i in bbdf['time']:
# ----> 3     new_time.append((int(i[0]) * 60) + (int(i[2:])))
#       4
#       5 bbdf['time'] = new_time
#
# ValueError: invalid literal for int() with base 10: '38,00 AM'

# %%
bbdf['time'] =  pd.to_datetime(bbdf['time'], format='%H:%M:%S.%f', infer_datetime_format=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-2e8c72e6d46f> in <module>()
# ----> 1 bbdf['time'] =  pd.to_datetime(bbdf['time'], format='%H:%M:%S.%f', infer_datetime_format=True)
#
# /Users/macbook/anaconda/lib/python2.7/site-packages/pandas/util/decorators.pyc in wrapper(*args, **kwargs)
#      89                 else:
#      90                     kwargs[new_arg_name] = new_arg_value
# ---> 91             return func(*args, **kwargs)
#      92         return wrapper
#      93     return _deprecate_kwarg
#
# /Users/macbook/anaconda/lib/python2.7/site-packages/pandas/tseries/tools.pyc in to_datetime(arg, errors, dayfirst, yearfirst, utc, box, format, exact, coerce, unit, infer_datetime_format)
#     289                         yearfirst=yearfirst,
#     290                         utc=utc, box=box, format=format, exact=exact,
# ...

# %%
bbdf['time'] = pd.to_datetime(bbdf['time'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-483f963e2d3c> in <module>()
# ----> 1 bbdf['time'] = pd.to_datetime(bbdf['time'])
#
# /Users/macbook/anaconda/lib/python2.7/site-packages/pandas/util/decorators.pyc in wrapper(*args, **kwargs)
#      89                 else:
#      90                     kwargs[new_arg_name] = new_arg_value
# ---> 91             return func(*args, **kwargs)
#      92         return wrapper
#      93     return _deprecate_kwarg
#
# /Users/macbook/anaconda/lib/python2.7/site-packages/pandas/tseries/tools.pyc in to_datetime(arg, errors, dayfirst, yearfirst, utc, box, format, exact, coerce, unit, infer_datetime_format)
#     289                         yearfirst=yearfirst,
#     290                         utc=utc, box=box, format=format, exact=exact,
# ...

# %%
pd.pivot_table(bbdf, index=['genre', 'time']).head(10)
# Out:
#                     x1st.week    year
# genre   time
# Country 2,36,00 AM       75.0  2000.0
#         2,53,00 AM       75.0  2000.0
#         2,55,00 AM       80.5  2000.0
#         2,56,00 AM       86.5  2000.0
#         2,58,00 AM       95.0  2000.0
#         3,02,00 AM       99.0  2000.0
#         3,03,00 AM       71.0  2000.0
#         3,04,00 AM       79.0  2000.0
#         3,05,00 AM       84.0  2000.0
#         3,07,00 AM       75.0  2000.0

# %%
bbdf.dropna(how='all', axis=1)
# Out:
#      year      artist.inverted  \
# 0    2000      Destiny's Child
# 1    2000              Santana
# 2    2000        Savage Garden
# 3    2000              Madonna
# 4    2000  Aguilera, Christina
# 5    2000                Janet
# 6    2000      Destiny's Child
# 7    2000    Iglesias, Enrique
# 8    2000                Sisqo
# 9    2000             Lonestar
# 10   2000               N'Sync
# 11   2000  Aguilera, Christina
# 12   2000     Vertical Horizon
# 13   2000                Creed
# 14   2000              Aaliyah
# 15   2000      matchbox twenty
# 16   2000        Carey, Mariah
# 17   2000          Hill, Faith
# 18   2000                  Mya
# 19   2000                Dream
# 20   2000        Braxton, Toni
# 21   2000        Anthony, Marc
# 22   2000                  98¡
# 23   2000      Destiny's Child
# 24   2000         3 Doors Down
# 25   2000                Sisqo
# 26   2000  Aguilera, Christina
# 27   2000     Houston, Whitney
# 28   2000                  Joe
# ...

# %%
bbdf['Time'].dtype
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-4da0ae4d7c92> in <module>()
# ----> 1 bbdf['Time'].dtype
#
# /Users/macbook/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1995             return self._getitem_multilevel(key)
#    1996         else:
# -> 1997             return self._getitem_column(key)
#    1998
#    1999     def _getitem_column(self, key):
#
# /Users/macbook/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    2002         # get column
#    2003         if self.columns.is_unique:
# -> 2004             return self._get_item_cache(key)
#    2005
#    2006         # duplicate columns & possible reduce dimensionality
#
# /Users/macbook/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in _get_item_cache(self, item)
# ...
