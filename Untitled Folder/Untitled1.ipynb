# %%
#import libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as plt
# %matplotlib inline 

from sklearn import datasets
from sklearn import linear_model
from sklearn.metrics import r2_score
from sklearn.cross_validation import train_test_split

from sklearn.cross_validation import cross_val_score
from sklearn.cross_validation import cross_val_predict
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

from textblob import TextBlob

# %%
df = pd.read_csv('all_data.csv', sep = '|')

# %%
df.head(1)
# Out:
#    Unnamed: 0  amt_pledged                                              blurb  \
# 0           0    8782571.0  this is a card game for people who are into ki...
#
#          category    new_category currency     goal         location  \
# 0  Tabletop Games  Tabletop Games      usd  10000.0  Los Angeles, CA
#
#    num_backers         num_backers_tier        ...         avg_tier_amount  \
# 0       219382  [15505, 202934, 200, 5]        ...                  163.75
#
#   median_tier_amount avg_num_backers_tier  median_num_backers_tier  \
# 0               67.5              54661.0                   7852.5
#
#    num_backers_bin                                  tier_backer_ratio  \
# 0                1  [7.091436307422111, 92.81480397358263, 0.09147...
#
#    num_tiers num_tiers_with_backers  project_updated unique_words_ratio
# 0          4                      4                0           0.894737
#
# [1 rows x 45 columns]

# %%
df.dtypes
# Out:
# Unnamed: 0                   int64
# amt_pledged                float64
# blurb                       object
# category                    object
# new_category                object
# currency                    object
# goal                       float64
# location                    object
# num_backers                  int64
# num_backers_tier            object
# pledge_tier                 object
# title                       object
# url                         object
# exchange_rate              float64
# pledged_USD                float64
# goal_USD                   float64
# percent_received           float64
# goal_level                  object
# goal_level_num               int64
# pledge_level                object
# pledge_level_num             int64
# creator                     object
# creator_names               object
# country                     object
# start                       object
# end                         object
# days                         int64
# ...

# %%
#Changed 'blurb' to ascii
df['blurb'] = df['blurb'].apply(lambda x: str(x).decode('unicode_escape').encode('ascii', 'ignore').strip())

# %%
df['sentiment'] = df['blurb'].apply(lambda x: TextBlob(x).sentiment.polarity)
df.head()
# Out:
#    Unnamed: 0  amt_pledged                                              blurb  \
# 0           0    8782571.0  this is a card game for people who are into ki...
# 1           1    6465690.0  an unusually addicting highquality desk toy de...
# 2           2    5408916.0  bring reading rainbows library of interactive ...
# 3           3    5702153.0  updated this is it were making a veronica mars...
# 4           4    3336371.0  an adventure game from tim schafer double fine...
#
#          category    new_category currency       goal           location  \
# 0  Tabletop Games  Tabletop Games      usd    10000.0    Los Angeles, CA
# 1  Product Design  Product Design      usd    15000.0         Denver, CO
# 2             Web     Documentary      usd  1000000.0    Los Angeles, CA
# 3  Narrative Film     Documentary      usd  2000000.0      San Diego, CA
# 4     Video Games     Video Games      usd   400000.0  San Francisco, CA
#
# ...

# %%
ax = df.plot.scatter('amt_pledged', 'sentiment', alpha = 0.1, c = 'purple')
ax.set_xlim(0, 500000)
#ax.set_ylim(0, 300000)
# Out:
# (0, 500000)

# %%
import seaborn as sns

# %%
sns.swarmplot(x = 'new_category', y = 'amt_pledged', hue = 'sentiment', data = df)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-8a81ea356ff5> in <module>()
# ----> 1 sns.swarmplot(x = 'new_category', y = 'amt_pledged', hue = 'sentiment', data = df)
#
# /Users/macbook/anaconda/lib/python2.7/site-packages/seaborn/categorical.pyc in swarmplot(x, y, hue, data, order, hue_order, split, orient, color, palette, size, edgecolor, linewidth, ax, **kwargs)
#    2737                        linewidth=linewidth))
#    2738
# -> 2739     plotter.plot(ax, kwargs)
#    2740     return ax
#    2741
#
# /Users/macbook/anaconda/lib/python2.7/site-packages/seaborn/categorical.pyc in plot(self, ax, kws)
#    1395     def plot(self, ax, kws):
#    1396         """Make the full plot."""
# -> 1397         self.draw_swarmplot(ax, kws)
#    1398         self.add_legend_data(ax)
#    1399         self.annotate_axes(ax)
#
# ...
